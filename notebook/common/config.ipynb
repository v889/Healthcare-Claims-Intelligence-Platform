# %%
dbutils.widgets.dropdown(
    "env",
    "dev",
    ["dev", "qa", "prod"]
)

env = dbutils.widgets.get("env")

catalog_map = {
    "dev": "dev_healthcare",
    "qa": "qa_healthcare",
    "prod": "prod_healthcare"
}

catalog = catalog_map[env]

spark.sql(f"USE CATALOG {catalog}")
env_catalog=catalog
